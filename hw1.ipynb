# %% [markdown]
# # Homework One - Preparation for Machine Learning

# %% [markdown]
# ### Objective
# As a result of completing this exercise you should be able to:
#
# - Have prerequisite knowledge required for machine learning
# - Calculate derivatives and partial derivatives
# - Find optimized solutions, i.e., minimum and maximum
# - Identify sample space and event
# - Calculate the probability of event
# - Estimate expected value in probability
# - Implement basic python codes
# - Make plots using `matplotlib` package in Python
# - Create vectors and matrices using `numpy` package in Python
# - Load data in to Python using `pandas` in Python

# %% [markdown]
# ### Before you start:
# #### **Show your work** to get **full credit**
# - If you prefer to type your work electroncially, use *Markdown cells* to type your equations, work, and answers.
#
# **or**
#
# - If you prefer use paper to do calcuation, take a photo of your manual work on paper (write neatly!), save the photo to the *"image" folder* under your "HW1" folder, and display your image in Jupyter Notebook using a code cell
#     - The code and image example below show you how to use the *Image* Class in *IPython.display* Module to present a image called "example.jpg" in the "images" folder under than same directory, in which this Jupyter Notebook is.
#     - Note: Remember to replace the image name by the name of your image

# %%
from IPython.display import Image
Image(filename='./images/example.jpg', width=250)

# %% [markdown]
# #### Useful resources to create or display content using Markdown in Jupyter Notebook
# * Intro
#     * https://www.dataquest.io/blog/jupyter-notebook-tutorial/
# * Markdown cheat sheet
#     * https://www.markdownguide.org/cheat-sheet/
# * math or equations in Markdown
#     * https://g14n.info/2014/09/math-on-github-pages/
#     * https://paperhive.org/help/markdown#formulas
#     * https://www.maths.tcd.ie/~dwilkins/LaTeXPrimer/Calculus.html
# * IPython display module
#     * https://ipython.readthedocs.io/en/stable/api/generated/IPython.display.html

# %% [markdown]
# #### Refresh your python skills and get familiar with useful packages or modules, please check out the Jupyter Notebooks posted under "In Class Exercise" on Canvas in "Week 1" module

# %% [markdown]
# ## Calculus

# %% [markdown]
# #### 1. Given that $f(x) = 7x^2 + 10$, what is the derivative of $f(x)$? (Show your answer and work below)

# %% [markdown]
# 7 * 2 = 14. Exponent of 2 reduces by 1. 10 has no variable so it dissapears.

# %% [markdown]
# $\frac{d}{dx}f(x)=14x$

# %% [markdown]
# #### 2. Follow Question 1 above, What is the x value for the minimum or maximum value of $f(x)$? (Show your answer and work below)

# %% [markdown]
# (Markdown cell: Type your solution here)

# %%
# or Code cell: display your image of manual work here

# %% [markdown]
# #### 3. Given that $f(x) = 2e^{3x}$, what is the derivative of $f(x)$? (Show your answer and work below)

# %% [markdown]
# $\frac{d}{dx}f(x)=$

# %% [markdown]
# (Markdown cell: Type your solution here)

# %%
# or Code cell: display your image of manual work here

# %% [markdown]
# #### 4. Given that $f(x, y) = 5x^2+2x^2y+3y+1$, what is the parital derivative of $f(x,y)$? (Show your answer and work below)

# %% [markdown]
# $\frac{\partial}{\partial x}f(x, y)=$

# %% [markdown]
# (Markdown cell: Type your solution here)

# %%
# or Code cell: display your image of manual work here

# %% [markdown]
# $\frac{\partial}{\partial y}f(x, y)=$

# %% [markdown]
# (Markdown cell: Type your solution here)

# %%
# or Code cell: display your image of manual work here

# %% [markdown]
# ## Probability

# %% [markdown]
# #### 5. We have a fair coin that has the same chance of landing heads up or tails up. What is the probability of getting heads, tails, and tails after we flip it three times?  (Show your answer and work below)

# %% [markdown]
# $p(heads, tails, tails) = p(heads \cap tails \cap tails) = $

# %% [markdown]
# (Markdown cell: Type your solution here)

# %%
# or Code cell: display your image of manual work here

# %% [markdown]
# #### 6. If we have an unfair coin that has $2/5$ of the chance to land heads up. What is the probability of seeing four tails after we flip the coin four times? (Show your answer and work below)

# %% [markdown]
# $p(tails, tails, tails, tails)= $

# %% [markdown]
# (Markdown cell: Type your solution here)

# %%
# or Code cell: display your image of manual work here

# %% [markdown]
# #### 7. Now you are using the unfair coin described in Question 6 above play in a coin flip game. In the game, you will flip the coin once and be awarded two dollars if the coin landing heads up and one dollar otherwise. What is the expected value of the amount you get in the game? Given X as the number of dollars you will be awarded, find $E[X]$. (Show your answer and work below)

# %% [markdown]
# $E[X]= $

# %% [markdown]
# (Markdown cell: Type your solution here)

# %%
# or Code cell: display your image of manual work here

# %% [markdown]
# ## Basic Python

# %% [markdown]
# ### Conditional Statement

# %% [markdown]
# #### 8. Please write a if-elif-else program which identify and print out a person's weight category based on the input of that person's BMI value.
# | BMI | Weight Category |
# | ----------- | ----------- |
# | BMI $\lt$ 18.5 | underweight |
# | 18.5 $\le$ BMI $\lt$ 25 | healthy |
# | 25 $\le$ BMI $\lt$ 30 | overweight |
# | 30 $\le$ BMI | obses |
#
# For example, if the input is 22, the output of the program should be "healthy".
#
# (Write your codes below)

# %%
# BMI classification
# Write your code here

bmi = int(input())


if bmi >= 30:
    print("Obese")
elif bmi >= 25.5 and x < 30:
    print("Overweight")
elif bmi >= 18.5 and x < 25:
    print("Healthy")
elif bmi < 18.5:
    print("Underweight")
else:
    print("Not valid weight")
# Out:
# 16
# Underweight

# %% [markdown]
# ### Loops

# %% [markdown]
# #### 9. Please write a function,called n_pattern, with nested loops that takes an input value n and print out the following pattern:
# 1\
# 12\
# 123\
# ....\
# 123....n
#
# For example:
# - if the input n is 2, the ouput pattern will be\
# 1\
# 12
#
# - if the input is 4, the output pattern will be\
# 1\
# 12\
# 123\
# 1234
#
# At the end, please call your function and test it with a input value you like.

# %%
# Number Pattern
# Write your function below

# %%
# Call your n_pattern function here with a input value n you select
# Write your code here

# %% [markdown]
# ## Load the Data into Python using *pandas*

# %% [markdown]
# #### 10. Please load the housing data (a csv file called "housing.csv") into Python (Jupyter Notebook) using `pandas` package. The housing dataset is under the "datasets" folder under "HW1". Once you load it, please show the first five rows of your data.
# Note: The is a header row in the csv file
#
# (Write your codes below)

# %%
# Import the pandas package

# %%
#  Load the csv file

# %%
# Show the first five rows of the DataFrame

# %% [markdown]
# ## Make a Plot using *matplotlib*

# %% [markdown]
# #### 11. Make a historgram of the "median_income" column in the housing data using `matplotlib` package.
# (Write your codes below)

# %%
# Import the package

# %%
# plot the histogram of median_income column in the housing dataset

# %% [markdown]
# ## Vector and Matrics using *numpy*

# %% [markdown]
# #### 12. Let try some basic functions in numpy package, which we will use a lot for linear algebra.
# Please first use the numpy package to create a two dimensional array  $$\begin{bmatrix}1 & 2 & 3\\4 & 5 & 6\end{bmatrix}$$ using the `array` method. Then, transpose the array using `transpose` method.

# %%
# Import the package

# %%
# Create your 2D array

# %%
# Transpose the array you created above

# %% [markdown]
# ## Quick Survey

# %% [markdown]
# How long did it take you to complete this homework?

# %% [markdown]
# (Type your response here)

# %% [markdown]
# Which sections or questions take most of the time?

# %% [markdown]
# (Type your response here)
